# %% [markdown]
# # **TASK-3**

# %%
countries = {
    "US": "United States", "IN": "India", "GB": "United Kingdom", "FR": "France", "DE": "Germany",
    "JP": "Japan", "CN": "China", "BR": "Brazil", "ZA": "South Africa", "RU": "Russia",
    "AU": "Australia", "CA": "Canada", "IT": "Italy", "ES": "Spain", "MX": "Mexico",
    "KR": "South Korea", "ID": "Indonesia", "NL": "Netherlands", "SA": "Saudi Arabia", "TR": "Turkey",
    "AR": "Argentina", "CH": "Switzerland", "SE": "Sweden", "NG": "Nigeria", "PL": "Poland",
    "BE": "Belgium", "TH": "Thailand", "IR": "Iran", "AT": "Austria", "PK": "Pakistan",
    "MY": "Malaysia", "PH": "Philippines", "SG": "Singapore", "CO": "Colombia", "BD": "Bangladesh",
    "VN": "Vietnam", "AE": "United Arab Emirates", "GR": "Greece", "UA": "Ukraine",
    "IL": "Israel", "NO": "Norway", "FI": "Finland", "DK": "Denmark",
    "CZ": "Czech Republic", "PT": "Portugal", "RO": "Romania", "HU": "Hungary", "NZ": "New Zealand",
    "IE": "Ireland", "PE": "Peru", "KE": "Kenya", "VE": "Venezuela", "EC": "Ecuador",
    "DZ": "Algeria", "MA": "Morocco", "EG": "Egypt", "GH": "Ghana", "SK": "Slovakia",
    "BG": "Bulgaria", "HR": "Croatia", "LT": "Lithuania", "SI": "Slovenia", "LV": "Latvia",
    "EE": "Estonia", "SR": "Serbia", "BO": "Bolivia", "TT": "Trinidad and Tobago", "KW": "Kuwait",
    "OM": "Oman", "CY": "Cyprus", "LU": "Luxembourg", "MT": "Malta", "PY": "Paraguay",
    "IS": "Iceland", "MU": "Mauritius", "QA": "Qatar", "PA": "Panama", "LK": "Sri Lanka",
    "BH": "Bahrain", "JM": "Jamaica", "DO": "Dominican Republic", "GT": "Guatemala", "UY": "Uruguay",
    "NP": "Nepal", "HN": "Honduras", "SV": "El Salvador", "BZ": "Belize", "MG": "Madagascar",
    "AL": "Albania", "AM": "Armenia", "AZ": "Azerbaijan", "BY": "Belarus", "GE": "Georgia",
    "MD": "Moldova", "ME": "Montenegro", "MK": "North Macedonia", "RS": "Serbia", "TJ": "Tajikistan"
}

# %%
import os
import requests
import csv
from bs4 import BeautifulSoup

dataset_folder = "national_data"
flags_folder = os.path.join(dataset_folder, "flags")
anthems_folder = os.path.join(dataset_folder, "anthems")
music_folder = os.path.join(dataset_folder, "anthems_mp3")

os.makedirs(flags_folder, exist_ok=True)
os.makedirs(anthems_folder, exist_ok=True)
os.makedirs(music_folder, exist_ok=True)

# %%
flag_base_url = "https://flagcdn.com/w640/"
anthem_base_url = "https://nationalanthems.info/"

# %%
data = []

# %%
for code, country in countries.items():
    print(f"Processing: {country}")

    # Download flag image
    flag_url = f"{flag_base_url}{code.lower()}.png"
    flag_path = os.path.join(flags_folder, f"{country}.png")

    flag_downloaded = False
    try:
        response = requests.get(flag_url)
        if response.status_code == 200:
            with open(flag_path, "wb") as f:
                f.write(response.content)
            flag_downloaded = True
            print(f"✔ Flag saved: {flag_path}")
    except Exception as e:
        print(f"❌ Flag download failed for {country}: {e}")

    # Append data
    data.append([country, flag_path if flag_downloaded else "N/A"])
# Out:
# Processing: United States
# ✔ Flag saved: national_data/flags/United States.png
# Processing: India
# ✔ Flag saved: national_data/flags/India.png
# Processing: United Kingdom
# ✔ Flag saved: national_data/flags/United Kingdom.png
# Processing: France
# ✔ Flag saved: national_data/flags/France.png
# Processing: Germany
# ✔ Flag saved: national_data/flags/Germany.png
# Processing: Japan
# ✔ Flag saved: national_data/flags/Japan.png
# Processing: China
# ✔ Flag saved: national_data/flags/China.png
# Processing: Brazil
# ✔ Flag saved: national_data/flags/Brazil.png
# Processing: South Africa
# ✔ Flag saved: national_data/flags/South Africa.png
# Processing: Russia
# ✔ Flag saved: national_data/flags/Russia.png
# Processing: Australia
# ✔ Flag saved: national_data/flags/Australia.png
# Processing: Canada
# ✔ Flag saved: national_data/flags/Canada.png
# Processing: Italy
# ✔ Flag saved: national_data/flags/Italy.png
# Processing: Spain
# ✔ Flag saved: national_data/flags/Spain.png
# Processing: Mexico
# ✔ Flag saved: national_data/flags/Mexico.png
# Processing: South Korea
# ✔ Flag saved: national_data/flags/South Korea.png
# Processing: Indonesia
# ✔ Flag saved: national_data/flags/Indonesia.png
# Processing: Netherlands
# ✔ Flag saved: national_data/flags/Netherlands.png
# Processing: Saudi Arabia
# ✔ Flag saved: national_data/flags/Saudi Arabia.png
# Processing: Turkey
# ✔ Flag saved: national_data/flags/Turkey.png
# Processing: Argentina
# ✔ Flag saved: national_data/flags/Argentina.png
# Processing: Switzerland
# ✔ Flag saved: national_data/flags/Switzerland.png
# Processing: Sweden
# ✔ Flag saved: national_data/flags/Sweden.png
# Processing: Nigeria
# ✔ Flag saved: national_data/flags/Nigeria.png
# Processing: Poland
# ✔ Flag saved: national_data/flags/Poland.png
# Processing: Belgium
# ✔ Flag saved: national_data/flags/Belgium.png
# Processing: Thailand
# ✔ Flag saved: national_data/flags/Thailand.png
# Processing: Iran
# ✔ Flag saved: national_data/flags/Iran.png
# Processing: Austria
# ✔ Flag saved: national_data/flags/Austria.png
# Processing: Pakistan
# ✔ Flag saved: national_data/flags/Pakistan.png
# Processing: Malaysia
# ✔ Flag saved: national_data/flags/Malaysia.png
# Processing: Philippines
# ✔ Flag saved: national_data/flags/Philippines.png
# Processing: Singapore
# ✔ Flag saved: national_data/flags/Singapore.png
# Processing: Colombia
# ✔ Flag saved: national_data/flags/Colombia.png
# Processing: Bangladesh
# ✔ Flag saved: national_data/flags/Bangladesh.png
# Processing: Vietnam
# ✔ Flag saved: national_data/flags/Vietnam.png
# Processing: United Arab Emirates
# ✔ Flag saved: national_data/flags/United Arab Emirates.png
# Processing: Greece
# ✔ Flag saved: national_data/flags/Greece.png
# Processing: Ukraine
# ✔ Flag saved: national_data/flags/Ukraine.png
# Processing: Israel
# ✔ Flag saved: national_data/flags/Israel.png
# Processing: Norway
# ✔ Flag saved: national_data/flags/Norway.png
# Processing: Finland
# ✔ Flag saved: national_data/flags/Finland.png
# Processing: Denmark
# ✔ Flag saved: national_data/flags/Denmark.png
# Processing: Czech Republic
# ✔ Flag saved: national_data/flags/Czech Republic.png
# Processing: Portugal
# ✔ Flag saved: national_data/flags/Portugal.png
# Processing: Romania
# ✔ Flag saved: national_data/flags/Romania.png
# Processing: Hungary
# ✔ Flag saved: national_data/flags/Hungary.png
# Processing: New Zealand
# ✔ Flag saved: national_data/flags/New Zealand.png
# Processing: Ireland
# ✔ Flag saved: national_data/flags/Ireland.png
# Processing: Peru
# ✔ Flag saved: national_data/flags/Peru.png
# Processing: Kenya
# ✔ Flag saved: national_data/flags/Kenya.png
# Processing: Venezuela
# ✔ Flag saved: national_data/flags/Venezuela.png
# Processing: Ecuador
# ✔ Flag saved: national_data/flags/Ecuador.png
# Processing: Algeria
# ✔ Flag saved: national_data/flags/Algeria.png
# Processing: Morocco
# ✔ Flag saved: national_data/flags/Morocco.png
# Processing: Egypt
# ✔ Flag saved: national_data/flags/Egypt.png
# Processing: Ghana
# ✔ Flag saved: national_data/flags/Ghana.png
# Processing: Slovakia
# ✔ Flag saved: national_data/flags/Slovakia.png
# Processing: Bulgaria
# ✔ Flag saved: national_data/flags/Bulgaria.png
# Processing: Croatia
# ✔ Flag saved: national_data/flags/Croatia.png
# Processing: Lithuania
# ✔ Flag saved: national_data/flags/Lithuania.png
# Processing: Slovenia
# ✔ Flag saved: national_data/flags/Slovenia.png
# Processing: Latvia
# ✔ Flag saved: national_data/flags/Latvia.png
# Processing: Estonia
# ✔ Flag saved: national_data/flags/Estonia.png
# Processing: Serbia
# ✔ Flag saved: national_data/flags/Serbia.png
# Processing: Bolivia
# ✔ Flag saved: national_data/flags/Bolivia.png
# Processing: Trinidad and Tobago
# ✔ Flag saved: national_data/flags/Trinidad and Tobago.png
# Processing: Kuwait
# ✔ Flag saved: national_data/flags/Kuwait.png
# Processing: Oman
# ✔ Flag saved: national_data/flags/Oman.png
# Processing: Cyprus
# ✔ Flag saved: national_data/flags/Cyprus.png
# Processing: Luxembourg
# ✔ Flag saved: national_data/flags/Luxembourg.png
# Processing: Malta
# ✔ Flag saved: national_data/flags/Malta.png
# Processing: Paraguay
# ✔ Flag saved: national_data/flags/Paraguay.png
# Processing: Iceland
# ✔ Flag saved: national_data/flags/Iceland.png
# Processing: Mauritius
# ✔ Flag saved: national_data/flags/Mauritius.png
# Processing: Qatar
# ✔ Flag saved: national_data/flags/Qatar.png
# Processing: Panama
# ✔ Flag saved: national_data/flags/Panama.png
# Processing: Sri Lanka
# ✔ Flag saved: national_data/flags/Sri Lanka.png
# Processing: Bahrain
# ✔ Flag saved: national_data/flags/Bahrain.png
# Processing: Jamaica
# ✔ Flag saved: national_data/flags/Jamaica.png
# Processing: Dominican Republic
# ✔ Flag saved: national_data/flags/Dominican Republic.png
# Processing: Guatemala
# ✔ Flag saved: national_data/flags/Guatemala.png
# Processing: Uruguay
# ✔ Flag saved: national_data/flags/Uruguay.png
# Processing: Nepal
# ✔ Flag saved: national_data/flags/Nepal.png
# Processing: Honduras
# ✔ Flag saved: national_data/flags/Honduras.png
# Processing: El Salvador
# ✔ Flag saved: national_data/flags/El Salvador.png
# Processing: Belize
# ✔ Flag saved: national_data/flags/Belize.png
# Processing: Madagascar
# ✔ Flag saved: national_data/flags/Madagascar.png
# Processing: Albania
# ✔ Flag saved: national_data/flags/Albania.png
# Processing: Armenia
# ✔ Flag saved: national_data/flags/Armenia.png
# Processing: Azerbaijan
# ✔ Flag saved: national_data/flags/Azerbaijan.png
# Processing: Belarus
# ✔ Flag saved: national_data/flags/Belarus.png
# Processing: Georgia
# ✔ Flag saved: national_data/flags/Georgia.png
# Processing: Moldova
# ✔ Flag saved: national_data/flags/Moldova.png
# Processing: Montenegro
# ✔ Flag saved: national_data/flags/Montenegro.png
# Processing: North Macedonia
# ✔ Flag saved: national_data/flags/North Macedonia.png
# Processing: Serbia
# ✔ Flag saved: national_data/flags/Serbia.png
# Processing: Tajikistan
# ✔ Flag saved: national_data/flags/Tajikistan.png

# %%
import os
import pandas as pd


# Load CSV file
csv_path = "/content/anthems.csv"
df = pd.read_csv(csv_path)

# Ensure correct column names (modify if necessary)
df.columns = [col.lower().strip() for col in df.columns]
english_column = "anthem"
country_column = "alpha-2"

# Iterate and create files
for code,country in countries.items():
    anthem_text = df[df[country_column] == code][english_column]
    file_path = os.path.join(anthems_folder, f"{country}.txt")
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(anthem_text.iloc[0])

print("Files created successfully!")
# Out:
# Files created successfully!

# %%
def download_mp3(mp3_url, country_name):

    save_path = os.path.join("national_data/anthems_mp3", f"{country_name}.mp3")

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36",
        "Referer": "https://nationalanthems.info/",
    }

    try:
        response = requests.get(mp3_url, headers=headers, stream=True)
        if response.status_code == 200:
            with open(save_path, "wb") as file:
                for chunk in response.iter_content(1024):  # Download in chunks
                    file.write(chunk)
            print(f"Downloaded: {save_path}")
        else:
            print(f"Failed to download {country_name}'s anthem. HTTP Status: {response.status_code}")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading {country_name}'s anthem: {e}")

for code,country in countries.items():
  download_mp3(f"https://nationalanthems.info/{code.lower()}.mp3", country)
# Out:
# Downloaded: national_data/anthems_mp3/United States.mp3
# Downloaded: national_data/anthems_mp3/India.mp3
# Downloaded: national_data/anthems_mp3/United Kingdom.mp3
# Downloaded: national_data/anthems_mp3/France.mp3
# Downloaded: national_data/anthems_mp3/Germany.mp3
# Downloaded: national_data/anthems_mp3/Japan.mp3
# Downloaded: national_data/anthems_mp3/China.mp3
# Downloaded: national_data/anthems_mp3/Brazil.mp3
# Downloaded: national_data/anthems_mp3/South Africa.mp3
# Downloaded: national_data/anthems_mp3/Russia.mp3
# Downloaded: national_data/anthems_mp3/Australia.mp3
# Downloaded: national_data/anthems_mp3/Canada.mp3
# Downloaded: national_data/anthems_mp3/Italy.mp3
# Downloaded: national_data/anthems_mp3/Spain.mp3
# Downloaded: national_data/anthems_mp3/Mexico.mp3
# Downloaded: national_data/anthems_mp3/South Korea.mp3
# Downloaded: national_data/anthems_mp3/Indonesia.mp3
# Downloaded: national_data/anthems_mp3/Netherlands.mp3
# Downloaded: national_data/anthems_mp3/Saudi Arabia.mp3
# Downloaded: national_data/anthems_mp3/Turkey.mp3
# Downloaded: national_data/anthems_mp3/Argentina.mp3
# Downloaded: national_data/anthems_mp3/Switzerland.mp3
# Downloaded: national_data/anthems_mp3/Sweden.mp3
# Downloaded: national_data/anthems_mp3/Nigeria.mp3
# Downloaded: national_data/anthems_mp3/Poland.mp3
# Downloaded: national_data/anthems_mp3/Belgium.mp3
# Downloaded: national_data/anthems_mp3/Thailand.mp3
# Downloaded: national_data/anthems_mp3/Iran.mp3
# Downloaded: national_data/anthems_mp3/Austria.mp3
# Downloaded: national_data/anthems_mp3/Pakistan.mp3
# Downloaded: national_data/anthems_mp3/Malaysia.mp3
# Downloaded: national_data/anthems_mp3/Philippines.mp3
# Downloaded: national_data/anthems_mp3/Singapore.mp3
# Downloaded: national_data/anthems_mp3/Colombia.mp3
# Downloaded: national_data/anthems_mp3/Bangladesh.mp3
# Downloaded: national_data/anthems_mp3/Vietnam.mp3
# Downloaded: national_data/anthems_mp3/United Arab Emirates.mp3
# Downloaded: national_data/anthems_mp3/Greece.mp3
# Downloaded: national_data/anthems_mp3/Ukraine.mp3
# Downloaded: national_data/anthems_mp3/Israel.mp3
# Downloaded: national_data/anthems_mp3/Norway.mp3
# Downloaded: national_data/anthems_mp3/Finland.mp3
# Downloaded: national_data/anthems_mp3/Denmark.mp3
# Downloaded: national_data/anthems_mp3/Czech Republic.mp3
# Downloaded: national_data/anthems_mp3/Portugal.mp3
# Downloaded: national_data/anthems_mp3/Romania.mp3
# Downloaded: national_data/anthems_mp3/Hungary.mp3
# Downloaded: national_data/anthems_mp3/New Zealand.mp3
# Downloaded: national_data/anthems_mp3/Ireland.mp3
# Downloaded: national_data/anthems_mp3/Peru.mp3
# Downloaded: national_data/anthems_mp3/Kenya.mp3
# Downloaded: national_data/anthems_mp3/Venezuela.mp3
# Downloaded: national_data/anthems_mp3/Ecuador.mp3
# Downloaded: national_data/anthems_mp3/Algeria.mp3
# Downloaded: national_data/anthems_mp3/Morocco.mp3
# Downloaded: national_data/anthems_mp3/Egypt.mp3
# Downloaded: national_data/anthems_mp3/Ghana.mp3
# Downloaded: national_data/anthems_mp3/Slovakia.mp3
# Downloaded: national_data/anthems_mp3/Bulgaria.mp3
# Downloaded: national_data/anthems_mp3/Croatia.mp3
# Downloaded: national_data/anthems_mp3/Lithuania.mp3
# Downloaded: national_data/anthems_mp3/Slovenia.mp3
# Downloaded: national_data/anthems_mp3/Latvia.mp3
# Downloaded: national_data/anthems_mp3/Estonia.mp3
# Downloaded: national_data/anthems_mp3/Serbia.mp3
# Downloaded: national_data/anthems_mp3/Bolivia.mp3
# Downloaded: national_data/anthems_mp3/Trinidad and Tobago.mp3
# Downloaded: national_data/anthems_mp3/Kuwait.mp3
# Downloaded: national_data/anthems_mp3/Oman.mp3
# Failed to download Cyprus's anthem. HTTP Status: 404
# Downloaded: national_data/anthems_mp3/Luxembourg.mp3
# Downloaded: national_data/anthems_mp3/Malta.mp3
# Downloaded: national_data/anthems_mp3/Paraguay.mp3
# Downloaded: national_data/anthems_mp3/Iceland.mp3
# Downloaded: national_data/anthems_mp3/Mauritius.mp3
# Downloaded: national_data/anthems_mp3/Qatar.mp3
# Downloaded: national_data/anthems_mp3/Panama.mp3
# Downloaded: national_data/anthems_mp3/Sri Lanka.mp3
# Downloaded: national_data/anthems_mp3/Bahrain.mp3
# Downloaded: national_data/anthems_mp3/Jamaica.mp3
# Downloaded: national_data/anthems_mp3/Dominican Republic.mp3
# Downloaded: national_data/anthems_mp3/Guatemala.mp3
# Downloaded: national_data/anthems_mp3/Uruguay.mp3
# Downloaded: national_data/anthems_mp3/Nepal.mp3
# Downloaded: national_data/anthems_mp3/Honduras.mp3
# Downloaded: national_data/anthems_mp3/El Salvador.mp3
# Downloaded: national_data/anthems_mp3/Belize.mp3
# Downloaded: national_data/anthems_mp3/Madagascar.mp3
# Downloaded: national_data/anthems_mp3/Albania.mp3
# Downloaded: national_data/anthems_mp3/Armenia.mp3
# Downloaded: national_data/anthems_mp3/Azerbaijan.mp3
# Downloaded: national_data/anthems_mp3/Belarus.mp3
# Downloaded: national_data/anthems_mp3/Georgia.mp3
# Downloaded: national_data/anthems_mp3/Moldova.mp3
# Downloaded: national_data/anthems_mp3/Montenegro.mp3
# Downloaded: national_data/anthems_mp3/North Macedonia.mp3
# Downloaded: national_data/anthems_mp3/Serbia.mp3
# Downloaded: national_data/anthems_mp3/Tajikistan.mp3

# %%
import csv

# Define the output file path
csv_file = "national_data/country_data.csv"

# Define the base paths for the files
base_path_lyrics = "national_data/anthems"
base_path_audio = "national_data/anthems_mp3"
base_path_flags = "national_data/flags"

# Write the data to a CSV file
with open(csv_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)

    # Write the header
    writer.writerow(["Country Code", "Country Name", "Lyrics File Path", "Audio File Path", "Flag Image Path"])

    # Write each country's data
    for code, country in countries.items():
        path_lyrics = f"{base_path_lyrics}/{country}.txt"
        path_audio = f"{base_path_audio}/{country}.mp3"
        path_flag = f"{base_path_flags}/{country}.png"

        writer.writerow([code, country, path_lyrics, path_audio, path_flag])

print(f"CSV file '{csv_file}' created successfully.")
# Out:
# CSV file 'national_data/country_data.csv' created successfully.

# %%
import shutil

shutil.make_archive("national_data", 'zip', "national_data")
from google.colab import files
files.download("national_data.zip")
